# %% [markdown]
# **Data Cleaning Assignment**

# %% [markdown]
# 1  . missing_counts = df.isnull().sum()
#      missing_percent = (df.isnull().sum() / len(df)) * 100
#      missing_report = pd.DataFrame({'Missing_Count': missing_counts, 'Missing_Percent': missing_percent})
#
#
# 2  . df['Age'].fillna(df['Age'].median(), inplace=True)
#
# 3  . df['Treatment_Cost'].fillna(df['Treatment_Cost'].median(),
#      inplace=True)
#
# 4  . duplicates = df.duplicated().sum()
#      df_clean = df.drop_duplicates()
#      size_before = len(df)
#      size_after = len(df_clean)
#
#      print(f"Rows before: {size_before}, Rows after: {size_after}, Removed: {size_before - size_after}")
#
# 5  . invalid_age = df[(df['Age'] < 0) | (df['Age'] > 100)]
#      df_clean = df[(df['Age'] >= 0) & (df['Age'] <= 100)]  # remove invalid rows
#
# 6  . Q1 = df['Treatment_Cost'].quantile(0.25)
#      Q3 = df['Treatment_Cost'].quantile(0.75)
#      IQR = Q3 - Q1
#      lower_bound = Q1 - 1.5 * IQR
#      upper_bound = Q3 + 1.5 * IQR
#
#      outliers = df[(df['Treatment_Cost'] < lower_bound) | (df['Treatment_Cost'] > upper_bound)]
#      num_outliers = len(outliers)
#
#      print(f"Number of outliers in Treatment_Cost: {num_outliers}")
#
# 7  . p5 = np.percentile(df['Treatment_Cost'], 5)
#      p95 = np.percentile(df['Treatment_Cost'], 95)
#      df['Treatment_Cost'] = np.clip(df['Treatment_Cost'], p5, p95)
#
# 8  . df['Log_Treatment_Cost'] = np.log(df['Treatment_Cost'])
#
#
# 9  . df = df.sort_values('Admission_Data')
#      df['Admission_Data'] = df['Admission_Data'].fillna(method='ffill')
